# %%
#Standards
# -*- coding: utf-8 -*-

import os  #to interact with the OS
import sys  #command line arguments
import re  #string patter matching
import glob  #file wildcards search
import math  
import pickle
import datetime
from time import time
from tqdm import tqdm, tnrange, tqdm_notebook  #progress bar for iteration
from pprint import pprint
import warnings
warnings.filterwarnings('ignore')  #ignore warning msg

#Wrangling
import numpy as np 
import pandas as pd  
import sklearn
import scipy as sp

#Pandas Config.
#For the default setting: reset_option(param) 
pd.set_option("display.max_rows", 100)  #출력할 행의 수
pd.set_option('display.max_columns', None)  #출력할 열의 수; None for the entire columns
pd.set_option('display.max_colwidth', 1000)  #열의 너비; None for the entire columns
pd.set_option('display.float_format', lambda x: '%.3f' % x)  # Format scientific notation from Pandas
#pd.options.display.float_format = '{:.5f}'.format

# Ignore warnings
import warnings
warnings.filterwarnings('ignore', category = FutureWarning)

# %autosave 120
# Out:
# Autosaving every 120 seconds

# %%
#Visualization
import matplotlib
import matplotlib.pyplot as plt  #visualization
from matplotlib import font_manager, rc #Matplotlib Config.
import seaborn as sns 

#interactive viz
import ipywidgets as widgets
from IPython.display import display

rc('font', family='AppleGothic')
matplotlib.style.use('ggplot')  #fivethirtyeight, seaborn
plt.rcParams['figure.figsize'] = (8, 6)
# plt.rcParams['font.family'] = 'serif'  #serif
# plt.rcParams['font.serif'] = 'Ubuntu'
# plt.rcParams['font.monospace'] = 'Ubuntu Mono'
plt.rcParams['font.size'] = 10
plt.rcParams['axes.labelsize'] = 10
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['xtick.labelsize'] = 8
plt.rcParams['ytick.labelsize'] = 8
plt.rcParams['legend.fontsize'] = 10
plt.rcParams['figure.titlesize'] = 12
plt.rcParams['axes.unicode_minus'] = False  #마이너스 깨짐 현상
# import matplotlib as mpl
# mpl.rc("figure", figsize=(24,12))

# %matplotlib inline

# %%
# !pwd

# %%
path = "../data/raw/"
# restaurant = pd.read_csv(path+"restaurant.csv").iloc[:,1:]
review = pd.read_csv(path+"restaurant_review.csv")
traffic = pd.read_csv(path+"traffic_count.csv")
# building = pd.read_csv(path+"building_240324_1212.csv")
building = pd.read_csv(path+"building_240327_1826.csv")

# %%
building.head()
# Out:
#    height  mpluto_bbl  cnstrct_yr                                globalid  \
# 0  59.723  1021210037    1910.000  {A0E56BCC-A86B-4CEF-9A42-9B4ECD61743F}
# 1 155.490  1008870001    1935.000  {0B06F7A8-1F83-44F3-97DD-AC524A6374CA}
# 2 167.214  1013490035    1931.000  {A091951D-C73E-4B77-9A61-716C666C5446}
# 3  28.570  1010610006    1910.000  {2BE9F674-67E7-4A49-8535-F636A16D8DA5}
# 4  73.130  1003060013    1900.000  {2403088E-77A6-4071-8B5E-D54AFBC720D9}
#
#        bin  office_area  retail_area  residential_area  OBJECTID  \
# 0  1062896            0         2250             10344    100007
# 1  1018457        50018         4000                 0    101045
# 2  1039988         2890            0             70110     99804
# 3  1026714            0            0                 0    103068
# 4  1003956            0         3800                 0     92425
#
#    street_width_min  street_width_max posted_speed  betweeness  \
# 0            60.000            60.000           25       0.012
# 1            32.000            32.000           25       0.028
# 2            60.000            60.000           25       0.012
# 3            32.000            32.000           25       0.023
# 4            34.000            45.000           25       0.034
#
#    station_complex_id  ridership_evening  ridership_late_night  \
# 0                 149             54.059                22.605
# 1                 403            666.520                54.499
# 2                 612           1625.486                98.033
# 3                 162            489.674                80.554
# 4                 231            687.781                58.691
#
#    ridership_midday  ridership_morning  ridership_night  \
# 0           104.186            104.288           19.346
# 1           589.012            290.296          248.617
# 2          1074.659            341.607          460.167
# 3           498.985            220.548          326.712
# 4           674.359            211.021          295.261
#
#    distance_from_station(ft)  idw_aadt_2019  idw_aadt_2020  idw_aadt_2021  \
# 0                    705.645      13651.723      15362.930      17083.134
# 1                    302.952      10065.446      10282.944      11495.144
# 2                   1397.998      14437.630      14445.844      16299.638
# 3                   1620.037      10455.418      10087.378      11238.596
# 4                    291.564       7632.300       7433.878       8351.143
#
#    idw_atvc_2018  idw_atvc_2019  idw_atvc_2020
# 0        110.061        140.829        332.411
# 1        129.011        178.320        272.447
# 2        151.953        174.349        240.654
# 3        163.403        182.998        237.267
# 4        105.344        137.101        350.242

# %%
review.sort_values("name")
# Out:
#               neighborhood                             name  \
# 2413        Hudson Heights  1601 Dominican Valle Restaurant
# 784                   NoHo                   218 Restaurant
# 581              Kip's Bay                   218 Restaurant
# 1920     Flatiron District                   218 Restaurant
# 684   Meatpacking District                   218 Restaurant
# ...                    ...                              ...
# 1529          Midtown East                         wagamama
# 759            Murray Hill                         wagamama
# 1586          Sutton Place                         wagamama
# 1360       Columbus Circle                         wagamama
# 698   Meatpacking District                         wagamama
#
#                          place_id  price_level  rating  user_ratings_total  \
# 2413  ChIJLQSqXhv0wokRHnXgtBBBn-M        2.000   3.800                 116
# 784   ChIJY6y3bohZwokR0wAvTPRvLAM        1.000   4.200                 167
# 581   ChIJY6y3bohZwokR0wAvTPRvLAM        1.000   4.200                 167
# 1920  ChIJY6y3bohZwokR0wAvTPRvLAM        1.000   4.200                 167
# 684   ChIJY6y3bohZwokR0wAvTPRvLAM        1.000   4.200                 167
# ...                           ...          ...     ...                 ...
# 1529  ChIJucC69nVZwokRmziSfSAfhFA        2.000   4.300                 669
# 759   ChIJucC69nVZwokRmziSfSAfhFA        2.000   4.300                 669
# 1586  ChIJucC69nVZwokRmziSfSAfhFA        2.000   4.300                 669
# 1360  ChIJucC69nVZwokRmziSfSAfhFA        2.000   4.300                 669
# 698   ChIJucC69nVZwokRmziSfSAfhFA        2.000   4.300                 669
#
#      business_status  adr_address                         formatted_address  \
# 2413     OPERATIONAL          NaN  1601 St Nicholas Ave, New York, NY 10040
# 784      OPERATIONAL          NaN          218 Grand St, New York, NY 10013
# 581      OPERATIONAL          NaN          218 Grand St, New York, NY 10013
# 1920     OPERATIONAL          NaN          218 Grand St, New York, NY 10013
# 684      OPERATIONAL          NaN          218 Grand St, New York, NY 10013
# ...              ...          ...                                       ...
# 1529     OPERATIONAL          NaN         100 W 55th St, New York, NY 10019
# 759      OPERATIONAL          NaN         100 W 55th St, New York, NY 10019
# 1586     OPERATIONAL          NaN         100 W 55th St, New York, NY 10019
# 1360     OPERATIONAL          NaN         100 W 55th St, New York, NY 10019
# 698      OPERATIONAL          NaN         100 W 55th St, New York, NY 10019
#
#         lat     lng      bin  distance
# 2413 40.855 -73.930  1064035     0.000
# 784  40.719 -73.996  1006933     0.000
# 581  40.719 -73.996  1006933     0.000
# 1920 40.719 -73.996  1006933     0.000
# 684  40.719 -73.996  1006933     0.000
# ...     ...     ...      ...       ...
# 1529 40.763 -73.979  1083719     0.000
# 759  40.763 -73.979  1083719     0.000
# 1586 40.763 -73.979  1083719     0.000
# 1360 40.763 -73.979  1083719     0.000
# 698  40.763 -73.979  1083719     0.000
#
# [3057 rows x 13 columns]

# %%
building.columns
# Out:
# Index(['height', 'mpluto_bbl', 'cnstrct_yr', 'globalid', 'bin', 'office_area',
#        'retail_area', 'residential_area', 'OBJECTID', 'street_width_min',
#        'street_width_max', 'posted_speed', 'betweeness', 'station_complex_id',
#        'ridership_evening', 'ridership_late_night', 'ridership_midday',
#        'ridership_morning', 'ridership_night', 'distance_from_station(ft)',
#        'idw_aadt_2019', 'idw_aadt_2020', 'idw_aadt_2021', 'idw_atvc_2018',
#        'idw_atvc_2019', 'idw_atvc_2020'],
#       dtype='object')

# %%
building.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37409 entries, 0 to 37408
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   height                     37200 non-null  float64
#  1   mpluto_bbl                 37409 non-null  int64
#  2   cnstrct_yr                 36751 non-null  float64
#  3   globalid                   37409 non-null  object
#  4   bin                        37409 non-null  int64
#  5   office_area                37409 non-null  int64
#  6   retail_area                37409 non-null  int64
#  7   residential_area           37409 non-null  int64
#  8   OBJECTID                   37409 non-null  int64
#  9   street_width_min           33284 non-null  float64
#  10  street_width_max           33226 non-null  float64
#  11  posted_speed               37409 non-null  object
#  12  betweeness                 37409 non-null  float64
#  13  station_complex_id         37409 non-null  int64
#  14  ridership_evening          37409 non-null  float64
#  15  ridership_late_night       37409 non-null  float64
#  16  ridership_midday           37409 non-null  float64
#  17  ridership_morning          37409 non-null  float64
#  18  ridership_night            37409 non-null  float64
#  19  distance_from_station(ft)  37409 non-null  float64
#  20  idw_aadt_2019              37409 non-null  float64
#  21  idw_aadt_2020              37409 non-null  float64
#  22  idw_aadt_2021              37409 non-null  float64
#  23  idw_atvc_2018              37409 non-null  float64
#  24  idw_atvc_2019              37409 non-null  float64
#  25  idw_atvc_2020              37409 non-null  float64
# dtypes: float64(17), int64(7), object(2)
# memory usage: 7.4+ MB

# %%
# restaurant
building.head()
# Out:
#    height  mpluto_bbl  cnstrct_yr                                globalid  \
# 0  59.723  1021210037    1910.000  {A0E56BCC-A86B-4CEF-9A42-9B4ECD61743F}
# 1 155.490  1008870001    1935.000  {0B06F7A8-1F83-44F3-97DD-AC524A6374CA}
# 2 167.214  1013490035    1931.000  {A091951D-C73E-4B77-9A61-716C666C5446}
# 3  28.570  1010610006    1910.000  {2BE9F674-67E7-4A49-8535-F636A16D8DA5}
# 4  73.130  1003060013    1900.000  {2403088E-77A6-4071-8B5E-D54AFBC720D9}
#
#        bin  office_area  retail_area  residential_area  OBJECTID  \
# 0  1062896            0         2250             10344    100007
# 1  1018457        50018         4000                 0    101045
# 2  1039988         2890            0             70110     99804
# 3  1026714            0            0                 0    103068
# 4  1003956            0         3800                 0     92425
#
#    street_width_min  street_width_max posted_speed  betweeness  \
# 0            60.000            60.000           25       0.012
# 1            32.000            32.000           25       0.028
# 2            60.000            60.000           25       0.012
# 3            32.000            32.000           25       0.023
# 4            34.000            45.000           25       0.034
#
#    station_complex_id  ridership_evening  ridership_late_night  \
# 0                 149             54.059                22.605
# 1                 403            666.520                54.499
# 2                 612           1625.486                98.033
# 3                 162            489.674                80.554
# 4                 231            687.781                58.691
#
#    ridership_midday  ridership_morning  ridership_night  \
# 0           104.186            104.288           19.346
# 1           589.012            290.296          248.617
# 2          1074.659            341.607          460.167
# 3           498.985            220.548          326.712
# 4           674.359            211.021          295.261
#
#    distance_from_station(ft)  idw_aadt_2019  idw_aadt_2020  idw_aadt_2021  \
# 0                    705.645      13651.723      15362.930      17083.134
# 1                    302.952      10065.446      10282.944      11495.144
# 2                   1397.998      14437.630      14445.844      16299.638
# 3                   1620.037      10455.418      10087.378      11238.596
# 4                    291.564       7632.300       7433.878       8351.143
#
#    idw_atvc_2018  idw_atvc_2019  idw_atvc_2020
# 0        110.061        140.829        332.411
# 1        129.011        178.320        272.447
# 2        151.953        174.349        240.654
# 3        163.403        182.998        237.267
# 4        105.344        137.101        350.242

# %%
# df = building.copy()
df = building[['cnstrct_yr',
               'height', 
                # 'mpluto_bbl', 
                # 'globalid', 
                'office_area',
                'retail_area', 
                'residential_area', 
                # 'OBJECTID', 
                'street_width_min',
                'street_width_max', 
                'posted_speed', 
                'betweeness', 
                # 'GTFS Stop ID',
                'ridership_evening', 
                'ridership_late_night', 
                'ridership_midday',
                'ridership_morning', 
                'ridership_night',
                'distance_from_station(ft)', 
                'idw_aadt_2019', 
                'idw_aadt_2020',
                # 'idw_aadt_2021', 
                # 'idw_atvc_2018', 
                'idw_atvc_2019', 
                'idw_atvc_2020'
               ]].copy()

# %%
df
# Out:
#        cnstrct_yr  height  office_area  retail_area  residential_area  \
# 0        1910.000  59.723            0         2250             10344
# 1        1935.000 155.490        50018         4000                 0
# 2        1931.000 167.214         2890            0             70110
# 3        1910.000  28.570            0            0                 0
# 4        1900.000  73.130            0         3800                 0
# ...           ...     ...          ...          ...               ...
# 37404    2012.000  26.006         5000         5000                 0
# 37405    1923.000  35.448            0            0                 0
# 37406    2023.000 338.000            0            0                 0
# 37407    1925.000  84.720        23039         2000                 0
# 37408    1900.000  53.480            0            0              1680
#
#        street_width_min  street_width_max posted_speed  betweeness  \
# 0                60.000            60.000           25       0.012
# 1                32.000            32.000           25       0.028
# 2                60.000            60.000           25       0.012
# 3                32.000            32.000           25       0.023
# 4                34.000            45.000           25       0.034
# ...                 ...               ...          ...         ...
# 37404            40.000            40.000           25       0.020
# 37405            30.000            30.000           25       0.039
# 37406            20.000            22.000           25       0.011
# 37407            22.000            24.000           25       0.006
# 37408            70.000            70.000           25       0.033
#
#        ridership_evening  ridership_late_night  ridership_midday  \
# 0                 54.059                22.605           104.186
# 1                666.520                54.499           589.012
# 2               1625.486                98.033          1074.659
# 3                489.674                80.554           498.985
# 4                687.781                58.691           674.359
# ...                  ...                   ...               ...
# 37404            687.781                58.691           674.359
# 37405            250.515                26.992           322.543
# 37406           2296.975               138.171          1645.397
# 37407           2296.975               138.171          1645.397
# 37408            233.211                35.274           345.145
#
#        ridership_morning  ridership_night  distance_from_station(ft)  \
# 0                104.288           19.346                    705.645
# 1                290.296          248.617                    302.952
# 2                341.607          460.167                   1397.998
# 3                220.548          326.712                   1620.037
# 4                211.021          295.261                    291.564
# ...                  ...              ...                        ...
# 37404            211.021          295.261                    385.244
# 37405            216.469           71.749                    694.653
# 37406            875.980          650.946                    152.136
# 37407            875.980          650.946                    138.700
# 37408            253.380           70.393                   2054.372
#
#        idw_aadt_2019  idw_aadt_2020  idw_atvc_2019  idw_atvc_2020
# 0          13651.723      15362.930        140.829        332.411
# 1          10065.446      10282.944        178.320        272.447
# 2          14437.630      14445.844        174.349        240.654
# 3          10455.418      10087.378        182.998        237.267
# 4           7632.300       7433.878        137.101        350.242
# ...              ...            ...            ...            ...
# 37404       7757.683       7938.152        135.711        350.298
# 37405      12280.474      12612.833        149.614        274.145
# 37406       6615.447       6014.822        146.683        371.640
# 37407       8786.004       7764.175        147.024        372.501
# 37408      15087.895      16856.227        157.038        299.764
#
# [37409 rows x 19 columns]

# %% [markdown]
# # EDA

# %% [markdown]
# ## null values

# %%
df.isnull().sum()
# Out:
# cnstrct_yr                    658
# height                        209
# office_area                     0
# retail_area                     0
# residential_area                0
# street_width_min             4125
# street_width_max             4183
# posted_speed                    0
# betweeness                      0
# ridership_evening               0
# ridership_late_night            0
# ridership_midday                0
# ridership_morning               0
# ridership_night                 0
# distance_from_station(ft)       0
# idw_aadt_2019                   0
# idw_aadt_2020                   0
# idw_atvc_2019                   0
# idw_atvc_2020                   0
# dtype: int64

# %%
sns.heatmap(df.isnull(), cbar=False);

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# cnstrct_yr                   0
# height                       0
# office_area                  0
# retail_area                  0
# residential_area             0
# street_width_min             0
# street_width_max             0
# posted_speed                 0
# betweeness                   0
# ridership_evening            0
# ridership_late_night         0
# ridership_midday             0
# ridership_morning            0
# ridership_night              0
# distance_from_station(ft)    0
# idw_aadt_2019                0
# idw_aadt_2020                0
# idw_atvc_2019                0
# idw_atvc_2020                0
# dtype: int64

# %% [markdown]
# ## contruction year

# %%
df.groupby("cnstrct_yr").size().plot(alpha=.5, linestyle="--", label="annual")
df.groupby("cnstrct_yr").size().rolling(10).mean().plot(alpha=.9, label="10-year-avg")
# df.groupby("cnstrct_yr").size().rolling(30).mean().plot(alpha=.9)

plt.legend()

# %% [markdown]
# ## height
# - probably in ft unit
# - mean=88, but max=1550, suggesting there would be long-tailed distribution(right-skewed)

# %%
df["height"].describe()
# Out:
# count   20995.000
# mean       88.129
# std        89.621
# min         0.000
# 25%        46.710
# 50%        60.240
# 75%        86.195
# max      1550.000
# Name: height, dtype: float64

# %%
plt.boxplot(df[df["height"].lt(1600)]['height'],
            notch=1, # if 'True' then notched box plot
            sym='bs', # symbol: red square
            vert=0 # vertical : if 'False' then horizontal box plot
           )

# plt.ylim([0, 1600])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12849d050>,
#   <matplotlib.lines.Line2D at 0x128487e10>],
#  'caps': [<matplotlib.lines.Line2D at 0x12849e4d0>,
#   <matplotlib.lines.Line2D at 0x12849ef90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x12849c4d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x12849f990>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1284b8450>],
#  'means': []}

# %%
plt.hist(df['height'], 
         color = 'blue', 
         edgecolor = 'black', 
         bins=30);

# %% [markdown]
# ## area
# - office/retail/residential
# - it could be transformed into one column containing all three columns?
# - theoretically, possible options: OF, RT, RS, and, OFRT, OFRS, RTRS, ALL, NA
# - in this case, it may lose info about the ratio of occupied area by the respective type
# - it might be better to simply use it as is, or implement PCA

# %%
df["area_type"] = np.where((df["office_area"].ne(0)) & (df["retail_area"].ne(0)) & (df["residential_area"].ne(0)), "ALL", 
                            np.where((df["office_area"].ne(0)) & (df["retail_area"].ne(0)), "OFRT", 
                            np.where((df["office_area"].ne(0)) & (df["residential_area"].ne(0)), "OFRS",
                            np.where((df["retail_area"].ne(0)) & (df["residential_area"].ne(0)), "RTRS",
                                np.where(df["office_area"].ne(0), "OF",
                                np.where(df["retail_area"].ne(0), "RT",
                                np.where(df["residential_area"].ne(0), "RS", "NA")
                                        )
                                        )
                                    )
                                    )
                                    )
                          )

# %%
# df.head(30)
df["area_type"].value_counts(normalize=True).plot(kind="bar")
# Out:
# <Axes: xlabel='area_type'>

# %% [markdown]
# ## posted speed
# - there are many emptry-spaced records => replace it with NOLIMIT / NO INFO?
# - NO INFO: more likely, because the majority of records have less or equal to 25
# - Does this useful variable? prob not -- eg. diff of 5 means something?

# %%
df["posted_speed"].unique()
# Out:
# array(['25', '  ', '20', '40', '30', '50', '35', '45'], dtype=object)

# %%
df.groupby("posted_speed").size()
# Out:
# posted_speed
#        2508
# 20      964
# 25    17601
# 30       10
# 35        5
# 40       29
# 45        1
# 50        5
# dtype: int64

# %%
df.drop("posted_speed", axis=1, inplace=True)

# %% [markdown]
# ## betweenness
# -

# %%
df.head()
# Out:
#    cnstrct_yr  height  office_area  retail_area  residential_area  \
# 0    1910.000  59.723            0         2250             10344
# 1    1935.000 155.490        50018         4000                 0
# 2    1931.000 167.214         2890            0             70110
# 3    1910.000  28.570            0            0                 0
# 4    1900.000  73.130            0         3800                 0
#
#    street_width_min  street_width_max posted_speed  betweeness  \
# 0            60.000            60.000           25       0.012
# 1            32.000            32.000           25       0.028
# 2            60.000            60.000           25       0.012
# 3            32.000            32.000           25       0.023
# 4            34.000            45.000           25       0.034
#
#    distance_from_station(ft)  idw_aadt_2019  idw_aadt_2020  idw_atvc_2019  \
# 0                    705.429      13651.723      15362.930        140.829
# 1                    302.555      10065.446      10282.944        178.320
# 2                   1378.470      14437.630      14445.844        174.349
# 3                   1620.005      10455.418      10087.378        182.998
# 4                    292.273       7632.300       7433.878        137.101
#
#    idw_atvc_2020 area_type
# 0        332.411      RTRS
# 1        272.447      OFRT
# 2        240.654      OFRS
# 3        237.267        NA
# 4        350.242        RT

# %%
df["betweeness"].describe()
# Out:
# count   21123.000
# mean        0.019
# std         0.026
# min         0.000
# 25%         0.004
# 50%         0.009
# 75%         0.024
# max         0.327
# Name: betweeness, dtype: float64

# %%
plt.boxplot(df['betweeness'],
            notch=1, # if 'True' then notched box plot
            sym='bs', # symbol: red square
            vert=0 # vertical : if 'False' then horizontal box plot
           )

# plt.ylim([0, 1600])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12c2a08d0>,
#   <matplotlib.lines.Line2D at 0x12c2a0250>],
#  'caps': [<matplotlib.lines.Line2D at 0x12c2a1890>,
#   <matplotlib.lines.Line2D at 0x12c2a1e50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x128fd3dd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x12c2a2a90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12c2a3550>],
#  'means': []}

# %% [markdown]
# ## distance from station

# %%
df["distance_from_station(ft)"].describe()
# Out:
# count   21123.000
# mean      927.872
# std       716.260
# min         0.000
# 25%       492.714
# 50%       793.200
# 75%      1174.057
# max     10202.279
# Name: distance_from_station(ft), dtype: float64

# %%
plt.boxplot(df["distance_from_station(ft)"],
            notch=1, # if 'True' then notched box plot
            sym='bs', # symbol: red square
            vert=0 # vertical : if 'False' then horizontal box plot
           )

# plt.ylim([0, 1600])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12b51d350>,
#   <matplotlib.lines.Line2D at 0x12c20cb90>],
#  'caps': [<matplotlib.lines.Line2D at 0x12c20d910>,
#   <matplotlib.lines.Line2D at 0x12c20c590>],
#  'boxes': [<matplotlib.lines.Line2D at 0x12c1ee710>],
#  'medians': [<matplotlib.lines.Line2D at 0x12c20cd10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12c20d9d0>],
#  'means': []}

# %% [markdown]
# ## annual average daily traffic

# %%
df["idw_aadt_2019"].describe()
# Out:
# count   21123.000
# mean    11197.792
# std      4126.234
# min      3130.869
# 25%      8614.010
# 50%     10885.009
# 75%     12902.035
# max     98256.184
# Name: idw_aadt_2019, dtype: float64

# %% [markdown]
# ## annual average daily traffic count

# %%
df["idw_atvc_2019"].describe()
# Out:
# count   21123.000
# mean      158.106
# std        21.808
# min        55.514
# 25%       143.297
# 50%       155.505
# 75%       172.357
# max       604.226
# Name: idw_atvc_2019, dtype: float64

# %% [markdown]
# ## correlations

# %%
df.columns
# Out:
# Index(['cnstrct_yr', 'height', 'office_area', 'retail_area',
#        'residential_area', 'street_width_min', 'street_width_max',
#        'posted_speed', 'betweeness', 'distance_from_station(ft)',
#        'idw_aadt_2019', 'idw_aadt_2020', 'idw_atvc_2019', 'idw_atvc_2020',
#        'area_type'],
#       dtype='object')

# %%
#pairplot for pairwise relationships between variables 
sns.set()
cols = ['cnstrct_yr', 'height', 'office_area', 'retail_area',
       'residential_area','betweeness', 'distance_from_station(ft)',
       'idw_aadt_2019', 'idw_aadt_2020', 'idw_atvc_2019', 'idw_atvc_2020']
sns.pairplot(df[cols], corner=True, kind='reg', diag_kind='kde', #diag_kind='hist'
            #  hue='BldgType',
             diag_kws={'color':'green'},
             plot_kws={'scatter_kws': {'s':5, 'alpha': 0.5}, 'line_kws':{'color':'red'}})
# plt.legend()
plt.show();

# %% [markdown]
# # Modeling
# - handling mixed-typed data can be challenging
# - try to utilize algorithms like K-Prototypes

# %%
df.columns
# Out:
# Index(['cnstrct_yr', 'height', 'office_area', 'retail_area',
#        'residential_area', 'street_width_min', 'street_width_max',
#        'posted_speed', 'betweeness', 'ridership_evening',
#        'ridership_late_night', 'ridership_midday', 'ridership_morning',
#        'ridership_night', 'distance_from_station(ft)', 'idw_aadt_2019',
#        'idw_aadt_2020', 'idw_atvc_2019', 'idw_atvc_2020'],
#       dtype='object')

# %%
df.head()
# Out:
#    cnstrct_yr  height  office_area  retail_area  residential_area  \
# 0    1910.000  59.723            0         2250             10344
# 1    1935.000 155.490        50018         4000                 0
# 2    1931.000 167.214         2890            0             70110
# 3    1910.000  28.570            0            0                 0
# 4    1900.000  73.130            0         3800                 0
#
#    street_width_min  street_width_max posted_speed  betweeness  \
# 0            60.000            60.000           25       0.012
# 1            32.000            32.000           25       0.028
# 2            60.000            60.000           25       0.012
# 3            32.000            32.000           25       0.023
# 4            34.000            45.000           25       0.034
#
#    ridership_evening  ridership_late_night  ridership_midday  \
# 0             54.059                22.605           104.186
# 1            666.520                54.499           589.012
# 2           1625.486                98.033          1074.659
# 3            489.674                80.554           498.985
# 4            687.781                58.691           674.359
#
#    ridership_morning  ridership_night  distance_from_station(ft)  \
# 0            104.288           19.346                    705.645
# 1            290.296          248.617                    302.952
# 2            341.607          460.167                   1397.998
# 3            220.548          326.712                   1620.037
# 4            211.021          295.261                    291.564
#
#    idw_aadt_2019  idw_aadt_2020  idw_atvc_2019  idw_atvc_2020
# 0      13651.723      15362.930        140.829        332.411
# 1      10065.446      10282.944        178.320        272.447
# 2      14437.630      14445.844        174.349        240.654
# 3      10455.418      10087.378        182.998        237.267
# 4       7632.300       7433.878        137.101        350.242

# %%
X = df[[
       'cnstrct_yr', 'height', 'office_area', 'retail_area',
       'residential_area',
       'betweeness', 
       'ridership_evening',
       'ridership_late_night', 'ridership_midday', 'ridership_morning',
       'ridership_night',
       'distance_from_station(ft)',
       'idw_aadt_2019', 'idw_aadt_2020', 'idw_atvc_2019', 'idw_atvc_2020',
       # 'area_type'
       ]]

# %%
from sklearn.preprocessing import StandardScaler

# Standardize the combined dataset
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.decomposition import PCA

# Perform PCA for dimensionality reduction
pca = PCA()  #n_components=6
# X_pca = pca.fit_transform(X_scaled)

# %%
# Explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_
print("Explained variance ratio:", explained_variance_ratio)

# Cumulative explained variance ratio
cumulative_explained_variance_ratio = explained_variance_ratio.cumsum()
print("Cumulative explained variance ratio:", cumulative_explained_variance_ratio)
# Out:
# Explained variance ratio: [0.29721966 0.14418153 0.10505112 0.08253208 0.06945665 0.06192078
#  0.06016803 0.05451395 0.04345978 0.02989202 0.02493745 0.01314227
#  0.01149124 0.00091715 0.00069916 0.00041712]
# Cumulative explained variance ratio: [0.29721966 0.4414012  0.54645232 0.62898441 0.69844105 0.76036183
#  0.82052986 0.87504382 0.9185036  0.94839561 0.97333306 0.98647534
#  0.99796657 0.99888372 0.99958288 1.        ]

# %%
# Scree plot
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(pca.explained_variance_ratio_) + 1), pca.explained_variance_ratio_, marker='o', linestyle='-')
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.grid(True)
plt.show()

# %%
# Perform PCA for dimensionality reduction
pca = PCA(n_components=3)  #n_components=3
X_pca = pca.fit_transform(X_scaled)

# %% [markdown]
# ## DBSCAN

# %%
from sklearn.cluster import DBSCAN
# from sklearn.cluster import KMeans
# from sklearn.metrics import silhouette_score

# Instantiate and fit DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=5)
dbscan.fit(X_pca)
# Out:
# DBSCAN()

# %%
clusters = dbscan.fit_predict(X_pca)

# %%
# Visualize clustering 2-D
plt.figure(figsize=(10, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=clusters, cmap='viridis', marker='o', edgecolors='k')
plt.title('PCA + DBSCAN Clustering')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar(label='Cluster')
plt.grid(True)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D  # Import Axes3D from mpl_toolkits.mplot3d

# Visualize clustering in 3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')  # Create 3D axis

# Scatter plot for each cluster
for cluster_label in np.unique(clusters):
    cluster_mask = (clusters == cluster_label)
    ax.scatter(X_pca[cluster_mask, 0], X_pca[cluster_mask, 1], X_pca[cluster_mask, 2],
               label=f'Cluster {cluster_label}', cmap='viridis', marker='o', edgecolors='k')

# Set labels and title
ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')
ax.set_title('PCA + DBSCAN Clustering (3D)')
ax.legend()

plt.show()

# %%
X_pca_df = pd.DataFrame(X_pca)

# %%
X_pca_df["c"] = clusters

# %%
X_pca_df
# Out:
#            0      1      2   c
# 0     -2.089  0.025 -0.403   0
# 1      0.367  0.402  1.506   0
# 2      1.830  2.005  0.029   0
# 3      0.238  0.310 -0.298   0
# 4     -0.047 -2.334  0.567   0
# ...      ...    ...    ...  ..
# 32626 -0.056 -1.465  0.936   0
# 32627 -1.227  0.085 -0.215   0
# 32628  4.244 -0.776  2.824  15
# 32629  3.616 -1.648  0.041   6
# 32630 -1.267  1.104 -1.350   0
#
# [32631 rows x 4 columns]

# %%
X_pca_df['c'].value_counts()
# Out:
# c
#  0     30510
# -1       477
#  1       450
#  2       313
#  5       251
#  3       224
#  6       150
#  4       140
#  7        18
#  18       13
#  12       10
#  13       10
#  9        10
#  11        9
#  8         8
#  15        6
#  14        5
#  21        5
#  19        5
#  20        5
#  17        5
#  16        4
#  10        3
# Name: count, dtype: int64

# %%
dbscan.labels_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[145], line 1
# ----> 1 dbscan.labels_.value_counts()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'value_counts'

# %%
# Visualize clustering
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=dbscan.labels_, cmap='viridis')
plt.title('DBSCAN Clustering with PCA')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()
